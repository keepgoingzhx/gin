# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
#from google.colab.patches import cv2_imshow
import glob


#applying filter on a single image
def apply_filter(filename,filter):
    print("reading file---> "+str(filename))
    img=cv2.imread(filename,cv2.IMREAD_GRAYSCALE)

  #img=cv2.resize(img,(250,250))
  #comment out the above line if there is memory issue i.e. need to resize all images to smaller dim

    h, w = img.shape
    print("shape: "+str(h)+" x "+str(w)+"\n")

  # define filters
    horizontal = filter
    vertical = np.transpose(filter)

  # define images with 0s
    newhorizontalImage = np.zeros((h, w))
    newverticalImage = np.zeros((h, w))
    newgradientImage = np.zeros((h, w))

  # offset by 1
    for i in range(1, h - 1):
        for j in range(1, w - 1):
            horizontalGrad = (horizontal[0, 0] * img[i - 1, j - 1]) + \
                          (horizontal[0, 1] * img[i - 1, j]) + \
                          (horizontal[0, 2] * img[i - 1, j + 1]) + \
                          (horizontal[1, 0] * img[i, j - 1]) + \
                          (horizontal[1, 1] * img[i, j]) + \
                          (horizontal[1, 2] * img[i, j + 1]) + \
                          (horizontal[2, 0] * img[i + 1, j - 1]) + \
                          (horizontal[2, 1] * img[i + 1, j]) + \
                          (horizontal[2, 2] * img[i + 1, j + 1])

            newhorizontalImage[i - 1, j - 1] = abs(horizontalGrad)

            verticalGrad = (vertical[0, 0] * img[i - 1, j - 1]) + \
                        (vertical[0, 1] * img[i - 1, j]) + \
                        (vertical[0, 2] * img[i - 1, j + 1]) + \
                        (vertical[1, 0] * img[i, j - 1]) + \
                        (vertical[1, 1] * img[i, j]) + \
                        (vertical[1, 2] * img[i, j + 1]) + \
                        (vertical[2, 0] * img[i + 1, j - 1]) + \
                        (vertical[2, 1] * img[i + 1, j]) + \
                        (vertical[2, 2] * img[i + 1, j + 1])

            newverticalImage[i - 1, j - 1] = abs(verticalGrad)

          # Edge Magnitude
            mag = np.sqrt(pow(horizontalGrad, 2.0) + pow(verticalGrad, 2.0))
            newgradientImage[i - 1, j - 1] = mag

    return newgradientImage

#function for creating all edge-images of a directory
def convert_edge_dir(sourcedir,destdir):
    print("\n\n---reading directory "+sourcedir+"---\n")
    filecnt=1
    for filename in glob.glob(sourcedir+'/*'):
    #applying Prewitt filter
    #for appyling any other filter change filter value accordingly i.e. the 2nd args for apply_filter()
        imagemat=apply_filter(filename,np.array([[-1,0,1],[-1,0,1],[-1,0,1]]))
        cv2.imwrite(destdir+'/img-'+str(filecnt)+'.png',imagemat) #create the edge image and store it to consecutive filenames
        filecnt+=1
    print("\n\n--saved in "+destdir+"--\n")


#function for creating all edge-images under covid, non-covid, penumonia directories 
#since 4-class so COVID, NORMAL, Bacterial and Viral PNEUMONIA present
def convert_edge_all_dir(coviddir,bacdir,virdir,destdir):
    convert_edge_dir(coviddir,destdir+'/glioma')
    #convert_edge_dir(normdir,destdir+'/notumor')
    convert_edge_dir(bacdir,destdir+'/meningioma')
    convert_edge_dir(virdir,destdir+'/pituitary')
    print("\n---edge detection completed--\n")

#adjust the source paths accordingly
datasetdir='brain3'
gliomadir=datasetdir+'/glioma'
#notumordir=datasetdir+'/notumor'
meningiomadir=datasetdir+'/meningioma'
pituitarydir=datasetdir+'/pituitary'

#adjust the destination directory accordingly
#directory naming format--> <dataset_name(not necessary conventional)>_edge/<filtername>
destdir='brain3/Pretwitt'

convert_edge_all_dir(gliomadir,meningiomadir,pituitarydir,destdir)
# Out:
# ---reading directory brain3/glioma---
#
# reading file---> brain3/glioma\0.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\1.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\10.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\100.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\101.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\102.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\103.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\104.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\105.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\106.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\107.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\108.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\109.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\11.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\110.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\111.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\112.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\113.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\114.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\115.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\116.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\117.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\118.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\119.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\12.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\120.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\121.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\122.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\123.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\124.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\125.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\126.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\127.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\128.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\129.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\13.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\130.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\131.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\132.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\133.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\134.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\135.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\136.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\137.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\138.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\139.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\14.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\140.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\141.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\142.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\143.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\144.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\145.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\15.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\156.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\16.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\168.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\169.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\17.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\170.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\171.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\172.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\173.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\174.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\175.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\176.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\177.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\178.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\179.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\18.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\180.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\181.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\182.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\183.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\184.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\185.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\186.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\187.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\188.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\189.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\19.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\190.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\191.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\192.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\193.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\194.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\195.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\196.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\197.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\198.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\199.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\20.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\21.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\22.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\23.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2300.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2301.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2302.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2308.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2309.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2310.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2311.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2312.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2313.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2314.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2320.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2321.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2322.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2323.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2324.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2325.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\2326.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\24.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\25.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\26.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\27.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\28.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\29.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\3.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\30.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\31.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\32.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\33.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\34.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\35.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\36.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\37.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\38.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\39.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\4.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\40.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\41.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\42.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\423.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\43.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\44.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\45.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\456.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\457.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\459.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\46.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\47.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\48.png
# shape: 512 x 512
# reading file---> brain3/glioma\49.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\5.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\50.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\51.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\52.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\53.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\54.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\55.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\56.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\57.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\58.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\59.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\6.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\60.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\61.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\62.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\63.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\64.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\65.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\66.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\67.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\68.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\69.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\7.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\70.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\71.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\72.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\73.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\74.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\75.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\76.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\77.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\78.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\79.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\8.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\80.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\81.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\82.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\83.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\84.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\85.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\86.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\87.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\88.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\89.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\9.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\90.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\91.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\92.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\93.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\94.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\95.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\96.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\97.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\98.png
# shape: 512 x 512
#
# reading file---> brain3/glioma\99.png
# shape: 512 x 512
#
#
#
# --saved in brain3/Pretwitt/glioma--
#
#
#
# ---reading directory brain3/meningioma---
#
# reading file---> brain3/meningioma\180.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\181.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\182.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\183.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\184.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\185.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\192.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\193.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\194.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\195.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\196.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\197.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2300.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2301.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2302.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2303.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2304.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2305.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2306.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2307.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2308.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2309.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2310.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2311.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2312.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2313.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2314.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2315.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2316.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2317.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2318.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2319.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2320.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2321.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2322.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2323.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2324.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2325.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2326.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2327.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2328.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2329.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2330.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2331.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2332.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2333.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2334.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2335.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2336.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2337.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2338.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2339.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2340.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2341.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2342.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2343.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2344.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2345.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2346.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2347.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2348.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2349.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2350.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2351.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2352.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2353.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2354.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2355.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2356.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2357.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2358.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2359.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2360.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2361.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2362.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2363.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2364.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2365.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2366.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2367.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2368.png
# shape: 512 x 512
# reading file---> brain3/meningioma\2369.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2370.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2371.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2372.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2373.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2374.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2375.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2376.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2377.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2378.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2379.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2380.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2381.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2382.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2383.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2384.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2385.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2386.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2387.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2388.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2389.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2390.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2391.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2392.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2393.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2394.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2395.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2396.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2397.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2398.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2399.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2400.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2401.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2402.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2403.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2404.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2405.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2406.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2407.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2408.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2409.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2410.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2411.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2412.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2413.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2414.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2415.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2416.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2417.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2418.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2419.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2420.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2421.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2422.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2423.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2424.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2425.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2426.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2427.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2428.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2429.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2430.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2431.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2432.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2433.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2434.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2435.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2436.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2437.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2438.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2439.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2440.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2441.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2442.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2443.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2444.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2445.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2446.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2447.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2448.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2449.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2450.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2451.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2452.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2453.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2454.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2455.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2456.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2457.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2458.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2459.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2460.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2461.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2462.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2463.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2464.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2465.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2466.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2467.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2468.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2469.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2470.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2471.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2472.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2473.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2474.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2475.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2476.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2477.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2478.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2479.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2480.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2481.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2482.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\2483.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\423.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\456.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\457.png
# shape: 512 x 512
#
# reading file---> brain3/meningioma\459.png
# shape: 512 x 512
#
#
#
# --saved in brain3/Pretwitt/meningioma--
#
#
#
# ---reading directory brain3/pituitary---
#
# reading file---> brain3/pituitary\1000.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1001.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1002.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1003.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1004.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1005.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1006.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1007.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1008.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1009.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1010.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1011.png
# shape: 512 x 512
# reading file---> brain3/pituitary\1012.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1013.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1014.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1015.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1016.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1017.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1018.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1019.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1020.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1021.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1022.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1023.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1024.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1025.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1026.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1027.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1028.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1029.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1030.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1031.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1032.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1033.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1034.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1035.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1063.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1064.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1065.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1066.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1067.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1068.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1069.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1070.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1071.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1072.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1081.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1082.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (1).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (2).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (3).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (4).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (5).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\111111 (6).png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1380.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1381.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1382.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1383.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1384.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1385.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1386.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1387.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1388.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1389.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1390.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1391.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1392.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1393.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1394.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1395.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1396.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1397.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1398.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1399.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1400.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1401.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1402.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1403.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1404.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1405.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1406.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1407.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1408.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1409.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1410.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1411.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1412.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1413.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1414.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1415.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1416.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1417.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1418.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1419.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1420.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1421.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1422.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1423.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\1424.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2300.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2301.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2302.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2308.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2309.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2310.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2311.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2312.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2313.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2314.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2320.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2321.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2322.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2323.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2324.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2325.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\2326.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\423.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\456.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\457.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\459.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\920.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\921.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\922.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\923.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\924.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\925.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\926.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\927.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\928.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\929.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\930.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\931.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\932.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\933.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\934.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\935.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\936.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\937.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\938.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\939.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\940.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\941.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\942.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\943.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\944.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\945.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\946.png
# shape: 512 x 512
# reading file---> brain3/pituitary\947.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\948.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\949.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\950.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\951.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\952.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\953.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\954.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\955.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\956.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\957.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\958.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\959.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\960.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\961.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\962.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\963.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\964.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\965.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\966.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\967.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\968.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\969.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\970.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\971.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\972.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\973.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\974.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\975.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\976.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\977.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\978.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\979.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\980.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\981.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\982.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\983.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\984.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\985.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\986.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\987.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\988.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\989.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\990.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\991.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\992.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\993.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\994.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\995.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\996.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\997.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\998.png
# shape: 512 x 512
#
# reading file---> brain3/pituitary\999.png
# shape: 512 x 512
#
#
#
# --saved in brain3/Pretwitt/pituitary--
#
#
# ---edge detection completed--
