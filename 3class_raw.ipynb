# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

from tensorflow.keras.layers import Input
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *

# %%
labels = ['glioma','meningioma','pituitary']

# %%
X_train = []
y_train = []
image_size = 128
for i in labels:
    folderPath = os.path.join('brain3',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        #x = os.path.join(folderPath,j)
        #img = img.resize(img,(image_size, image_size))
        #img=Image.open(x)
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 182.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 185.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 166.90it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
base_model1 = Xception(include_top = False ,input_shape=(image_size,image_size,3),weights='imagenet')
base_model2 = tf.keras.applications.ResNet50(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
base_model3 = tf.keras.applications.VGG16(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
base_model4 = tf.keras.applications.DenseNet201(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
base_model5 = tf.keras.applications.MobileNetV2(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
base_model6 = tf.keras.applications.EfficientNetB7(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
base_model7 = tf.keras.applications.InceptionV3(input_shape=(image_size,image_size,3),include_top=False,weights='imagenet')
inputs1 = base_model1.input
inputs2 = base_model2.input
inputs3 = base_model3.input
inputs4 = base_model4.input
inputs5 = base_model5.input
inputs6 = base_model6.input
inputs7 = base_model7.input

# %%
model1 = base_model1.output
model1 = tf.keras.layers.GlobalAveragePooling2D()(model1)
model1 = tf.keras.layers.Dropout(rate=0.5)(model1)
model1 = tf.keras.layers.Dense(3,activation='softmax')(model1)
model1 = tf.keras.models.Model(inputs=inputs1, outputs = model1)

model2 = base_model2.output
model2 = tf.keras.layers.GlobalAveragePooling2D()(model2)
model2 = tf.keras.layers.Dropout(rate=0.5)(model2)
model2 = tf.keras.layers.Dense(3,activation='softmax')(model2)
model2 = tf.keras.models.Model(inputs=inputs2, outputs = model2)

model3 = base_model3.output
model3 = tf.keras.layers.GlobalAveragePooling2D()(model3)
model3 = tf.keras.layers.Dropout(rate=0.5)(model3)
model3 = tf.keras.layers.Dense(3,activation='softmax')(model3)
model3 = tf.keras.models.Model(inputs=inputs3, outputs = model3)

model4 = base_model4.output
model4 = tf.keras.layers.GlobalAveragePooling2D()(model4)
model4 = tf.keras.layers.Dropout(rate=0.5)(model4)
model4 = tf.keras.layers.Dense(3,activation='softmax')(model4)
model4 = tf.keras.models.Model(inputs=inputs4, outputs = model4)

model5 = base_model5.output
model5 = tf.keras.layers.GlobalAveragePooling2D()(model5)
model5 = tf.keras.layers.Dropout(rate=0.5)(model5)
model5 = tf.keras.layers.Dense(3,activation='softmax')(model5)
model5 = tf.keras.models.Model(inputs=inputs5, outputs = model5)

model6 = base_model6.output
model6 = tf.keras.layers.GlobalAveragePooling2D()(model6)
model6 = tf.keras.layers.Dropout(rate=0.5)(model6)
model6 = tf.keras.layers.Dense(3,activation='softmax')(model6)
model6 = tf.keras.models.Model(inputs=inputs6, outputs = model6)

model7 = base_model7.output
model7 = tf.keras.layers.GlobalAveragePooling2D()(model7)
model7 = tf.keras.layers.Dropout(rate=0.5)(model7)
model7 = tf.keras.layers.Dense(3,activation='softmax')(model7)
model7 = tf.keras.models.Model(inputs=inputs7, outputs = model7)

# %%
model1.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model2.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model3.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model4.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model5.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model6.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model7.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


#his0=model0.fit(datagen.flow(x_train,y_train,batch_size=32),validation_data=(x_test,y_test),epochs=20)
hist1 = model1.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist2 = model2.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist3 = model3.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist4 = model4.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist5 = model5.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist6 = model6.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
hist7 = model7.fit(X_train,y_train,validation_split=0.1, epochs =50, batch_size=32)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 41s 2s/step - loss: 0.6520 - accuracy: 0.7407 - val_loss: 19.8434 - val_accuracy: 0.2778
# Epoch 2/50
# 16/16 [==============================] - 38s 2s/step - loss: 0.1939 - accuracy: 0.9498 - val_loss: 9.0571 - val_accuracy: 0.4444
# Epoch 3/50
# 16/16 [==============================] - 37s 2s/step - loss: 0.0539 - accuracy: 0.9844 - val_loss: 6.5987 - val_accuracy: 0.7222
# Epoch 4/50
# 16/16 [==============================] - 41s 3s/step - loss: 0.1133 - accuracy: 0.9709 - val_loss: 9.8436 - val_accuracy: 0.5556
# Epoch 5/50
# 16/16 [==============================] - 37s 2s/step - loss: 0.1192 - accuracy: 0.9680 - val_loss: 8.7513 - val_accuracy: 0.7222
# Epoch 6/50
# 16/16 [==============================] - 41s 3s/step - loss: 0.0420 - accuracy: 0.9901 - val_loss: 21.2142 - val_accuracy: 0.6111
# Epoch 7/50
# 16/16 [==============================] - 37s 2s/step - loss: 0.0286 - accuracy: 0.9941 - val_loss: 13.2340 - val_accuracy: 0.7778
# Epoch 8/50
# 16/16 [==============================] - 38s 2s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0
# 16/16 [==============================] - 142s 9s/step - loss: 0.0977 - accuracy: 0.9688 - val_loss: 0.4342 - val_accuracy: 0.9074
# Epoch 16/50
# 16/16 [==============================] - 139s 9s/step - loss: 0.0898 - accuracy: 0.9785 - val_loss: 0.2717 - val_accuracy: 0.9630
# Epoch 17/50
# 16/16 [==============================] - 145s 9s/step - loss: 0.0661 - accuracy: 0.9821 - val_loss: 1.6865 - val_accuracy: 0.9259
# Epoch 18/50
# 16/16 [==============================] - 147s 9s/step - loss: 0.1206 - accuracy: 0.9614 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 19/50
# 16/16 [==============================] - 148s 9s/step - loss: 0.1213 - accuracy: 0.9742 - val_loss: 0.8454 - val_accuracy: 0.8333
# Epoch 20/50
# 16/16 [==============================] - 147s 9s/step - loss: 0.0279 - accuracy: 0.9905 - val_loss: 0.0531 - val_accuracy: 0.9630
# Epoch 21/50
# 16/16 [==============================] - 149s 9s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 22/50
# 16/16 [==============================] - 145s 9s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 23/50
# 16/16 [==============================] - 142s 9s/step - loss: 9.3535e-04 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9815
# Epoch 24/50
# 16/16 [==============================] - 144s 9s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9630
# Epoch 25/50
# 16/16 [==============================] - 143s 9s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9630
# Epoch 26/50
# 16/16 [==============================] - 144s 9s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9815
# Epoch 27/50
# 16/16 [==============================] - 145s 9s/step - loss: 5.4364e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 28/50
# 16/16 [==============================] - 148s 9s/step - loss: 3.3004e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 29/50
# 16/16 [==============================] - 150s 9s/step - loss: 5.7200e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 30/50
# 16/16 [==============================] - 144s 9s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 31/50
# 16/16 [==============================] - 142s 9s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 32/50
# 16/16 [==============================] - 142s 9s/step - loss: 8.6075e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 33/50
# 16/16 [==============================] - 141s 9s/step - loss: 2.6845e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 34/50
# 16/16 [==============================] - 142s 9s/step - loss: 0.0102 - accuracy: 0.9934 - val_loss: 0.0347 - val_accuracy: 0.9815
# Epoch 35/50
# 16/16 [==============================] - 144s 9s/step - loss: 0.0070 - accuracy: 0.9964 - val_loss: 0.3525 - val_accuracy: 0.9630
# Epoch 36/50
# 16/16 [==============================] - 147s 9s/step - loss: 0.0215 - accuracy: 0.9970 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 37/50
# 16/16 [==============================] - 148s 9s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9815
# Epoch 38/50
# 16/16 [==============================] - 150s 9s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9815
# Epoch 39/50
# 16/16 [==============================] - 147s 9s/step - loss: 1.7521e-04 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9815
# Epoch 40/50
# 16/16 [==============================] - 148s 9s/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0660 - val_accuracy: 0.9815
# Epoch 41/50
# 16/16 [==============================] - 149s 9s/step - loss: 0.0181 - accuracy: 0.9946 - val_loss: 2.0516 - val_accuracy: 0.7222
# Epoch 42/50
# 16/16 [==============================] - 143s 9s/step - loss: 0.0784 - accuracy: 0.9600 - val_loss: 2.2548 - val_accuracy: 0.7222
# Epoch 43/50
# 16/16 [==============================] - 144s 9s/step - loss: 0.0892 - accuracy: 0.9818 - val_loss: 2.4605 - val_accuracy: 0.6667
# Epoch 44/50
50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.8889
# Epoch 22/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 1.0255 - val_accuracy: 0.8704
# Epoch 23/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.2618 - accuracy: 0.9321 - val_loss: 82.5894 - val_accuracy: 0.3889
# Epoch 24/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.1492 - accuracy: 0.9518 - val_loss: 2.7530 - val_accuracy: 0.6667
# Epoch 25/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0735 - accuracy: 0.9828 - val_loss: 0.5313 - val_accuracy: 0.8704
# Epoch 26/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0987 - accuracy: 0.9735 - val_loss: 1.9575 - val_accuracy: 0.4444
# Epoch 27/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0486 - accuracy: 0.9922 - val_loss: 3.0999 - val_accuracy: 0.4074
# Epoch 28/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0258 - accuracy: 0.9930 - val_loss: 2.1519 - val_accuracy: 0.6667
# Epoch 29/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.9004 - val_accuracy: 0.7963
# Epoch 30/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0485 - accuracy: 0.9866 - val_loss: 0.2896 - val_accuracy: 0.8889
# Epoch 31/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0148 - accuracy: 0.9990 - val_loss: 0.1253 - val_accuracy: 0.9444
# Epoch 32/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9815
# Epoch 33/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 34/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 35/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 36/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 37/50
# 16/16 [==============================] - 22s 1s/step - loss: 0.0612 - accuracy: 0.9798 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 38/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0499 - accuracy: 0.9851 - val_loss: 0.2810 - val_accuracy: 0.9444
# Epoch 39/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0402 - accuracy: 0.9922 - val_loss: 4.8617 - val_accuracy: 0.3519
# Epoch 40/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0531 - accuracy: 0.9803 - val_loss: 0.1036 - val_accuracy: 0.9630
# Epoch 41/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.1949 - accuracy: 0.9632 - val_loss: 8.1719 - val_accuracy: 0.5000
# Epoch 42/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0994 - accuracy: 0.9634 - val_loss: 0.2819 - val_accuracy: 0.8889
# Epoch 43/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9259
# Epoch 44/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9630
# Epoch 45/50
# 16/16 [==============================] - 22s 1s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9815
# Epoch 46/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 47/50
# 16/16 [==============================] - 20s 1s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 48/50
# 16/16 [==============================] - 20s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 49/50
# 16/16 [==============================] - 21s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 50/50
# 16/16 [==============================] - 2726s 182s/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.0060 - val_accuracy: 1.0000

# %%
pred1=model1.predict(X_test)
pred2=model2.predict(X_test)
pred3=model3.predict(X_test)
pred4=model4.predict(X_test)
pred5=model5.predict(X_test)
pred6=model6.predict(X_test)
pred7=model7.predict(X_test)

y_test_1=np.argmax(y_test,axis=1)
pred1=np.argmax(pred1,axis=1)
pred2=np.argmax(pred2,axis=1)
pred3=np.argmax(pred3,axis=1)
pred4=np.argmax(pred4,axis=1)
pred5=np.argmax(pred5,axis=1)
pred6=np.argmax(pred6,axis=1)
pred7=np.argmax(pred7,axis=1)

#ground = np.argmax(y_test,axis=1)
from sklearn.metrics import classification_report

print(classification_report(y_test_1,pred1,digits=4))
print(classification_report(y_test_1,pred2,digits=4))
print(classification_report(y_test_1,pred3,digits=4))
print(classification_report(y_test_1,pred4,digits=4))
print(classification_report(y_test_1,pred5,digits=4))
print(classification_report(y_test_1,pred6,digits=4))
print(classification_report(y_test_1,pred7,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9333    0.9655        15
#            1     0.9565    0.9565    0.9565        23
#            2     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9667        60
#    macro avg     0.9710    0.9633    0.9666        60
# weighted avg     0.9674    0.9667    0.9666        60
#
#               precision    recall  f1-score   support
#
#            0     0.5556    1.0000    0.7143        15
#            1     1.0000    0.3913    0.5625        23
#            2     0.9167    1.0000    0.9565        22
#
#     accuracy                         0.7667        60
#    macro avg     0.8241    0.7971    0.7444        60
# weighted avg     0.8583    0.7667    0.7449        60
#
#               precision    recall  f1-score   support
#
#            0     0.2500    1.0000    0.4000        15
#            1     0.0000    0.0000    0.0000        23
#            2     0.0000    0.0000    0.0000        22
#
#     accuracy                         0.2500        60
#    macro avg     0.0833    0.3333    0.1333        60
# weighted avg     0.0625    0.2500    0.1000        60
#
#               precision    recall  f1-score   support
#
#            0     0.9333    0.9333    0.9333        15
#            1     0.9545    0.9130    0.9333        23
#            2     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9500        60
#    macro avg     0.9481    0.9488    0.9481        60
# weighted avg     0.9500    0.9500    0.9496        60
#
#               precision    recall  f1-score   support
#
#            0     0.6250    1.0000    0.7692        15
#            1     0.4722    0.7391    0.5763        23
#            2     0.0000    0.0000    0.0000        22
#
#     accuracy                         0.5333        60
#    macro avg     0.3657    0.5797    0.4485        60
# weighted avg     0.3373    0.5333    0.4132        60
#
#               precision    recall  f1-score   support
#
#            0     0.7000    0.9333    0.8000        15
#            1     0.9412    0.6957    0.8000        23
#            2     0.9130    0.9545    0.9333        22
#
#     accuracy                         0.8500        60
#    macro avg     0.8514    0.8612    0.8444        60
# weighted avg     0.8706    0.8500    0.8489        60
#
#               precision    recall  f1-score   support
#
#            0     0.8824    1.0000    0.9375        15
#            1     1.0000    0.8696    0.9302        23
#            2     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9500        60
#    macro avg     0.9463    0.9565    0.9485        60
# weighted avg     0.9546    0.9500    0.9495        60
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import metrics
sum_confusion_matrix = metrics.confusion_matrix(y_test_1, pred7)
def cal_metrics(confusion_matrix):
    n_classes = confusion_matrix.shape[0]
    metrics_result = []
    for i in range(n_classes):
        # 逐步获取 真阳，假阳，真阴，假阴四个指标，并计算三个参数
        ALL = np.sum(confusion_matrix)
        # 对角线上是正确预测的
        TP = confusion_matrix[i, i]
        # 列加和减去正确预测是该类的假阳
        FP = np.sum(confusion_matrix[:, i]) - TP
        # 行加和减去正确预测是该类的假阴
        FN = np.sum(confusion_matrix[i, :]) - TP
        # 全部减去前面三个就是真阴
        TN = ALL - TP - FP - FN
        metrics_result.append([TP/(TP+FP), TP/(TP+FN), TN/(TN+FP),(TP+TN)/(TP+FP+FN+TN)])#pre、sen、spc，acc
        
    return metrics_result

# %%
spc = cal_metrics(sum_confusion_matrix)

# %%
spc_all=spc[0][2]+spc[1][2]+spc[2][2]
k = spc_all/3
k
# Out:
# 0.9764132553606238
